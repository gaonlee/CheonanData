# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib.font_manager as fm

plt.rc('font', family='Malgun Gothic')  # 맑은 고딕 폰트를 사용
plt.rcParams['axes.unicode_minus'] = False

# %%
DATA_PATH = "data"

# %%
df_floating_ca = pd.read_csv(f"{DATA_PATH}/TOTAL_SKT1_CA_SX_AGE_INFLOW_NOPE_MG.csv" , encoding='cp949')
df_floating_cn = pd.read_csv(f"{DATA_PATH}/TOTAL_SKT1_SX_AGE_FLOW_NOPE_MG.csv", encoding = 'cp949')

# %%
df_floating_cn
# Out:
#          기준년월일  시군구명  남성 10세미만 유동인구수  남성 10-14세 유동인구수  남성 15-19세 유동인구수  \
# 0     20240101   NaN        87359.50              NaN        119360.75
# 1     20240101   NaN        11215.66              NaN         17280.01
# 2     20240101   NaN        12678.15              NaN         18655.15
# 3     20240101   NaN        49574.89              NaN         62137.76
# 4     20240101   NaN        18177.34              NaN         31703.86
# ...        ...   ...             ...              ...              ...
# 2275  20240531   NaN         5977.83              NaN          4675.21
# 2276  20240531   NaN         2809.37              NaN          2315.04
# 2277  20240531   NaN        17000.06              NaN         13517.86
# 2278  20240531   NaN        10727.75              NaN          7789.66
# 2279  20240531   NaN         9625.41              NaN          6458.59
#
#       남성 20-24세 유동인구수  남성 25-29세 유동인구수  남성 30-34세 유동인구수  남성 35-39세 유동인구수  \
# ...

# %%
df_floating_ca
# Out:
# Empty DataFrame
# Columns: [기준년월일, 시군구명, 유입시군구코드, 남성 10세미만 유입인구수, 남성 10-14세 유입인구수, 남성 15-19세 유입인구수, 남성 20-24세 유입인구수, 남성 25-29세 유입인구수, 남성 30-34세 유입인구수, 남성 35-39세 유입인구수, 남성 40-44세 유입인구수, 남성 45-49세 유입인구수, 남성 50-54세 유입인구수, 남성 55-59세 유입인구수, 남성 60-64세 유입인구수, 남성 65-69세 유입인구수, 남성 70세이상 유입인구수, 여성 10세미만 유입인구수, 여성 10-14세 유입인구수, 여성 15-19세 유입인구수, 여성 20-24세 유입인구수, 여성 25-29세 유입인구수, 여성 30-34세 유입인구수, 여성 35-39세 유입인구수, 여성 40-44세 유입인구수, 여성 45-49세 유입인구수, 여성 50-54세 유입인구수, 여성 55-59세 유입인구수, 여성 60-64세 유입인구수, 여성 65-69세 유입인구수, 여성 70세이상 유입인구수]
# Index: []
#
# [0 rows x 31 columns]
